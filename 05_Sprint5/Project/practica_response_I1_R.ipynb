# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **¡Hola! Soy Dot, tu revisor de IA.**
#
# He completado la primera revisión de tu código. A continuación, encontrarás mis comentarios y sugerencias de mejora.
#
# **¿Qué debes hacer ahora?**
#
# 1. **Revisar:** Lee mis comentarios en el notebook más abajo.
# 2. **Decidir:**
# * **¿Estás de acuerdo con el feedback?** ¡Genial! Actualiza tu código según las sugerencias.
# * **¿No estás de acuerdo o crees que es un error?** ¡No hay problema! Puedes dejar tu código exactamente como está.
#
#
# 3. **Volver a enviar:** Envía tu proyecto de nuevo. **Tu próxima iteración será revisada por un experto humano**, independientemente de si hiciste cambios o no.
#
# -------------------------------------------------------------------------------------------------------------
# Mis comentarios están más abajo. **Te pido amablemente que no los muevas, modifiques ni elimines**.
#
# Verás mis comentarios resaltados en cuadros verdes, amarillos o rojos como estos:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Correcto. Todo se ha hecho exitosamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones.
# </div>

# %% [markdown]
# # ¿Cuál es la mejor tarifa?
#
# Trabajas como analista para el operador de telecomunicaciones Megaline. La empresa ofrece a sus clientes dos tarifas de prepago, Surf y Ultimate. El departamento comercial quiere saber cuál de las tarifas genera más ingresos para poder ajustar el presupuesto de publicidad.
#
# Vas a realizar un análisis preliminar de las tarifas basado en una selección de clientes relativamente pequeña. Tendrás los datos de 500 clientes de Megaline: quiénes son los clientes, de dónde son, qué tarifa usan, así como la cantidad de llamadas que hicieron y los mensajes de texto que enviaron en 2018. Tu trabajo es analizar el comportamiento de los clientes y determinar qué tarifa de prepago genera más ingresos.

# %% [markdown]
# [Te proporcionamos algunos comentarios para orientarte mientras completas este proyecto. Pero debes asegurarte de eliminar todos los comentarios entre corchetes antes de entregar tu proyecto.]
#
# [Antes de sumergirte en el análisis de datos, explica por tu propia cuenta el propósito del proyecto y las acciones que planeas realizar.]
#
# [Ten en cuenta que estudiar, modificar y analizar datos es un proceso iterativo. Es normal volver a los pasos anteriores y corregirlos/ampliarlos para permitir nuevos pasos.]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Las notas del template introductorio entre corchetes se dejaron en la entrega. Por favor, elimina todo el texto de guía entre corchetes y sustitúyelo por tu propio propósito/plan breve del proyecto (qué analizarás y los pasos clave que seguirás).
#
# </div>

# %% [markdown]
# ## Inicialización

# %%
# Cargar todas las librerías
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy import stats

# %% [markdown]
# ## Cargar datos

# %%
# Carga los archivos de datos en diferentes DataFrames
df_calls = pd.read_csv('datasets/megaline_calls.csv')
df_internet = pd.read_csv('datasets/megaline_internet.csv')
df_messages = pd.read_csv('datasets/megaline_messages.csv')
df_plans = pd.read_csv('datasets/megaline_plans.csv')
df_users = pd.read_csv('datasets/megaline_users.csv')

# %% [markdown]
# ## Preparar los datos

# %% [markdown]
# ## Tarifas

# %%
# Print the summary information of the plans DataFrame
df_plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 260.0+ bytes

# %%
# Print a sample ofn the plans DataFrame
df_plans.head(10)
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]
#
# **R.**
# Los tipos de datos y la información se ve correcta y completa

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Tu respuesta al resumen de datos es demasiado breve para lo que solicita la plantilla. Por favor, indica cualquier problema potencial (valores faltantes, dtypes/unidades incorrectos, inconsistencias de nombres) y cómo los abordarás. Por ejemplo, hay una discrepancia de nombres que debes reconocer (p. ej., `usd_monthly_pay` vs el esperado `usd_monthly_fee` en la descripción del proyecto/diccionario de datos), y deberías aclarar qué campo usarás más adelante en los cálculos de ingresos.
#
# </div>

# %% [markdown]
# ### Corregir datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# It's not identified the need to correct something

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Aunque creas que no se necesitan correcciones para la tabla `plans`, sería más sólido verificar explícitamente las expectativas clave (sin valores faltantes, unidades correctas como MB vs GB y tipos numéricos adecuados para los precios) en lugar de detenerte en `info()`/`head()`.
#
# </div>

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# it's not identified the need to enrich information

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta sección todavía no se ha abordado realmente. Considera añadir al menos un campo derivado que ayude en cálculos posteriores (por ejemplo, convertir los datos incluidos de MB a GB, o crear campos con unidades consistentes que usarás para comparaciones de excedentes), y explica brevemente por qué es útil.
#
# </div>

# %% [markdown]
# ## Usuarios/as

# %%
# Print the summary information of the users DataFrame
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
# Print a sample data for users
df_users.head()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]
#
# **R:**
# - Must be replace churn_date NaN values with 0 values, the users are active still

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Ten cuidado con cómo manejas el `churn_date` faltante. Reemplazar NaN por `0` mezcla tipos de fecha y numéricos y pierde el significado de “sigue activo”. Considera convertir `churn_date` a datetime y mantener los valores faltantes como NaT/NaN (o añadir un indicador separado como `is_active`).
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]
#
# **R.**
# - Count null values

# %%
df_users.isna().sum()
# Out:
# user_id         0
# first_name      0
# last_name       0
# age             0
# city            0
# reg_date        0
# plan            0
# churn_date    466
# dtype: int64

# %%
# Count duplicated values in users DataFrame
df_users.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - There are null values in churn_date, Doesn't exist duplicate values

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Must be replace churn_date NaN values with 0 values, the users are active still
df_users['churn_date'] = df_users['churn_date'].fillna(0)
# Verify the change
df_users.isna().sum()
# Out:
# user_id       0
# first_name    0
# last_name     0
# age           0
# city          0
# reg_date      0
# plan          0
# churn_date    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Recordatorio de un problema recurrente: evita rellenar campos de fecha faltantes (como `churn_date`) con `0`. Es preferible usar datetime + NaT (o un indicador de actividad separado), para que el filtrado posterior y el análisis basado en tiempo sigan siendo válidos.
#
# </div>

# %% [markdown]
# ## Llamadas

# %%
# Print the sumnary information of the calls Dataframe
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
# Print a sample of data calls
df_calls.head()
# Out:
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# 1  1000_145     1000  2018-12-27     13.66
# 2  1000_247     1000  2018-12-27     14.48
# 3  1000_309     1000  2018-12-28      5.76
# 4  1000_380     1000  2018-12-30      4.22

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]
#
# **R:**
#
# - The call_date is object type, must be change to datetime type

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# Validate if there are duplicate values
df_calls.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **R:**
#
# - There are no null or duplicate values

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# En el paso de llamadas “fix data”, concluyes que no hay valores nulos, pero solo verificaste duplicados. Considera agregar una comprobación explícita de valores faltantes (missing values) (y una breve interpretación) antes de continuar.
#
# </div>

# %%
# Convert call_date to datatime type
df_calls['call_date'] = pd.to_datetime(df_calls['call_date'])
# Verify the change
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  datetime64[ns]
#  3   duration   137735 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Month extraction from call_date
df_calls['month'] = df_calls['call_date'].dt.month
print(df_calls)
# Out:
#               id  user_id  call_date  duration  month
# 0        1000_93     1000 2018-12-27      8.52     12
# 1       1000_145     1000 2018-12-27     13.66     12
# 2       1000_247     1000 2018-12-27     14.48     12
# 3       1000_309     1000 2018-12-28      5.76     12
# 4       1000_380     1000 2018-12-30      4.22     12
# ...          ...      ...        ...       ...    ...
# 137730  1499_199     1499 2018-11-21      8.72     11
# 137731  1499_200     1499 2018-10-20     10.89     10
# 137732  1499_201     1499 2018-09-21      8.12      9
# 137733  1499_202     1499 2018-10-10      0.37     10
# 137734  1499_203     1499 2018-12-29     13.86     12
#
# [137735 rows x 5 columns]

# %% [markdown]
# ## Mensajes

# %%
# Print the summary information of the messages DataFrame
df_messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
# Print a sample of the messages data
df_messages.head()
# Out:
#          id  user_id message_date
# 0  1000_125     1000   2018-12-27
# 1  1000_160     1000   2018-12-31
# 2  1000_223     1000   2018-12-31
# 3  1000_251     1000   2018-12-27
# 4  1000_255     1000   2018-12-26

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La plantilla te pide que describas lo que observas en la tabla de mensajes (tipos de datos, valores faltantes, posibles problemas) y cómo los abordarías, pero falta este análisis escrito. Por favor, añade una breve narrativa (aunque la corrección principal sea convertir la columna de fecha a datetime).
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# Validate if there are duplicate values in messages DataFrame
df_messages.duplicated().sum()
# Validate if there are null values in messages DataFrame
df_messages.isna().sum()
# Out:
# id              0
# user_id         0
# message_date    0
# dtype: int64

# %% [markdown]
# **R:**
#
# There are not duplicate o null values in messages DataFrame

# %%
# Convert message_date to datatime type
df_messages['message_date'] = pd.to_datetime(df_messages['message_date'])
# Verify the chage
df_messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Extract month from message_date
df_messages['month'] = df_messages['message_date'].dt.month
print(df_messages)
# Out:
#              id  user_id message_date  month
# 0      1000_125     1000   2018-12-27     12
# 1      1000_160     1000   2018-12-31     12
# 2      1000_223     1000   2018-12-31     12
# 3      1000_251     1000   2018-12-27     12
# 4      1000_255     1000   2018-12-26     12
# ...         ...      ...          ...    ...
# 76046  1497_526     1497   2018-12-24     12
# 76047  1497_536     1497   2018-12-24     12
# 76048  1497_547     1497   2018-12-31     12
# 76049  1497_558     1497   2018-12-24     12
# 76050  1497_613     1497   2018-12-23     12
#
# [76051 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo convirtiendo `message_date` a datetime y creando una característica (feature) `month`—esto te prepara bien para las agregaciones mensuales requeridas más adelante.
#
# </div>

# %% [markdown]
# ## Internet

# %%
# Print the summary information of the internet DataFrame
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
# Print a sample of data for internet DataFrame
df_internet.head()
# Out:
#          id  user_id session_date  mb_used
# 0   1000_13     1000   2018-12-29    89.86
# 1  1000_204     1000   2018-12-31     0.00
# 2  1000_379     1000   2018-12-28   660.40
# 3  1000_413     1000   2018-12-26   270.99
# 4  1000_442     1000   2018-12-27   880.22

# %% [markdown]
# [Describe lo que ves y observas en la información general y en la muestra de datos impresa para el precio de datos anterior. ¿Hay algún problema (tipos de datos no adecuados, datos ausentes, etc.) que pudieran necesitar investigación y cambios adicionales? ¿Cómo se puede arreglar?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La plantilla te pide que describas lo que observas en la tabla de internet (tipos, valores faltantes, posibles anomalías) y cómo corregir cualquier problema, pero falta la explicación. Por favor, añade un breve análisis por escrito (aunque concluyas que la acción principal es convertir `session_date` a datetime).
#
# </div>

# %% [markdown]
# ### Corregir los datos

# %% [markdown]
# [Corrige los problemas obvios con los datos basándote en las observaciones iniciales.]

# %%
# Verify if there are duplicate values in internet DataFrame
df_internet.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Verify if there are null values in internet DataFrame
df_internet.isna().sum()
# Out:
# id              0
# user_id         0
# session_date    0
# mb_used         0
# dtype: int64

# %% [markdown]
# **R:**
# The are not duplicate or null values

# %%
# Convert session_date to datatime type
df_internet['session_date'] = pd.to_datetime(df_internet['session_date'])
# Verify the change
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  datetime64[ns]
#  3   mb_used       104825 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Enriquecer los datos

# %% [markdown]
# [Agrega factores adicionales a los datos si crees que pudieran ser útiles.]

# %%
# Extract month from session_date
df_internet['month'] = df_internet['session_date'].dt.month
df_internet
# Out:
#               id  user_id session_date  mb_used  month
# 0        1000_13     1000   2018-12-29    89.86     12
# 1       1000_204     1000   2018-12-31     0.00     12
# 2       1000_379     1000   2018-12-28   660.40     12
# 3       1000_413     1000   2018-12-26   270.99     12
# 4       1000_442     1000   2018-12-27   880.22     12
# ...          ...      ...          ...      ...    ...
# 104820  1499_215     1499   2018-10-20   218.06     10
# 104821  1499_216     1499   2018-12-30   304.72     12
# 104822  1499_217     1499   2018-09-22   292.75      9
# 104823  1499_218     1499   2018-12-07     0.00     12
# 104824  1499_219     1499   2018-12-24   758.31     12
#
# [104825 rows x 5 columns]

# %% [markdown]
# ## Estudiar las condiciones de las tarifas

# %% [markdown]
# [Es sumamente importante entender cómo funcionan las tarifas, cómo se les cobra a los usuarios en función de su plan de suscripción. Así que te sugerimos imprimir la información de la tarifa para ver una vez más sus condiciones.]

# %%
# Imprime las condiciones de la tarifa y asegúrate de que te quedan claras
df_plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Buen trabajo al volver a imprimir las condiciones del plan (minutos/SMS/datos incluidos y precios por excedente). Esto es exactamente lo que esta sección está pidiendo y respalda los cálculos de ingresos más adelante.
#
# </div>

# %% [markdown]
# ## Agregar datos por usuario
#
# [Ahora que los datos están limpios, agrega los datos por usuario y por periodo para que solo haya un registro por usuario y por periodo. Esto facilitará mucho el análisis posterior.]

# %%
# Calcula el número de llamadas hechas por cada usuario al mes. Guarda el resultado.

metrics_calls = df_calls.pivot_table(index=['user_id', 'month'], values='duration', aggfunc=['sum', 'count']).reset_index()
metrics_calls.columns = ['user_id', 'month', 'total_minute_duration', 'total_calls_count']
metrics_calls
# Out:
#       user_id  month  total_minute_duration  total_calls_count
# 0        1000     12                 116.83                 16
# 1        1001      8                 171.14                 27
# 2        1001      9                 297.69                 49
# 3        1001     10                 374.11                 65
# 4        1001     11                 404.59                 64
# ...       ...    ...                    ...                ...
# 2253     1498     12                 324.77                 39
# 2254     1499      9                 330.37                 41
# 2255     1499     10                 363.28                 53
# 2256     1499     11                 288.56                 45
# 2257     1499     12                 468.10                 65
#
# [2258 rows x 4 columns]

# %%
# Calcula la cantidad de minutos usados por cada usuario al mes. Guarda el resultado.
# Round the total minute duration to the upper integer, because the company charge by minute, and if the user use 1.5 minutes, the company charge 2 minutes.
def minute_round(row):
    return math.ceil(row)

metrics_calls['total_round_minutes'] = metrics_calls['total_minute_duration'].apply(minute_round)
metrics_calls = metrics_calls.loc[:, ['user_id', 'month', 'total_round_minutes', 'total_calls_count']]
metrics_calls
# Out:
#       user_id  month  total_round_minutes  total_calls_count
# 0        1000     12                  117                 16
# 1        1001      8                  172                 27
# 2        1001      9                  298                 49
# 3        1001     10                  375                 65
# 4        1001     11                  405                 64
# ...       ...    ...                  ...                ...
# 2253     1498     12                  325                 39
# 2254     1499      9                  331                 41
# 2255     1499     10                  364                 53
# 2256     1499     11                  289                 45
# 2257     1499     12                  469                 65
#
# [2258 rows x 4 columns]

# %%
# Calcula el número de mensajes enviados por cada usuario al mes. Guarda el resultado.

metrics_messages = df_messages.pivot_table(index=['user_id', 'month'], values='id', aggfunc='count')
metrics_messages.columns = ['total_messages']
metrics_messages.reset_index(inplace=True)
metrics_messages
# Out:
#       user_id  month  total_messages
# 0        1000     12              11
# 1        1001      8              30
# 2        1001      9              44
# 3        1001     10              53
# 4        1001     11              36
# ...       ...    ...             ...
# 1801     1496      9              21
# 1802     1496     10              18
# 1803     1496     11              13
# 1804     1496     12              11
# 1805     1497     12              50
#
# [1806 rows x 3 columns]

# %%
# Calcula el volumen del tráfico de Internet usado por cada usuario al mes. Guarda el resultado.

# Round mb according to the upper integer
def mb_round(row):
    return math.ceil(row)

metrics_internet = df_internet.pivot_table(index=['user_id', 'month'], values='mb_used', aggfunc='sum')
metrics_internet.reset_index(inplace=True)
metrics_internet['mb_used'] = metrics_internet['mb_used'].apply(mb_round)
metrics_internet
# Out:
#       user_id  month  mb_used
# 0        1000     12     1902
# 1        1001      8     6920
# 2        1001      9    13315
# 3        1001     10    22331
# 4        1001     11    18505
# ...       ...    ...      ...
# 2272     1498     12    23138
# 2273     1499      9    12985
# 2274     1499     10    19493
# 2275     1499     11    16814
# 2276     1499     12    22060
#
# [2277 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La facturación de Internet se está gestionando con el nivel de redondeo incorrecto. Según las reglas del proyecto, las sesiones individuales no se redondean; primero se suman los MB mensuales por usuario, luego se convierten a GB y se redondea hacia arriba el *total mensual* al siguiente GB entero para la facturación. Redondear los MB con `ceil` aquí inflará el uso y distorsionará los ingresos.
#
# </div>

# %% [markdown]
# [Junta los datos agregados en un DataFrame para que haya un registro que represente lo que consumió un usuario único en un mes determinado.]

# %%
# Fusiona los datos de llamadas, minutos, mensajes e Internet con base en user_id y month
# Merge calls users Dataframe to get the plan column
accumulated = metrics_calls.merge(metrics_messages, how='outer', on=['user_id', 'month'])
accumulated
# Out:
#       user_id  month  total_round_minutes  total_calls_count  total_messages
# 0        1000     12                117.0               16.0            11.0
# 1        1001      8                172.0               27.0            30.0
# 2        1001      9                298.0               49.0            44.0
# 3        1001     10                375.0               65.0            53.0
# 4        1001     11                405.0               64.0            36.0
# ...       ...    ...                  ...                ...             ...
# 2286     1498     12                325.0               39.0             NaN
# 2287     1499      9                331.0               41.0             NaN
# 2288     1499     10                364.0               53.0             NaN
# 2289     1499     11                289.0               45.0             NaN
# 2290     1499     12                469.0               65.0             NaN
#
# [2291 rows x 5 columns]

# %%
accumulated.info()
accumulated[accumulated['total_round_minutes'].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              2291 non-null   int64
#  1   month                2291 non-null   int32
#  2   total_round_minutes  2258 non-null   float64
#  3   total_calls_count    2258 non-null   float64
#  4   total_messages       1806 non-null   float64
# dtypes: float64(3), int32(1), int64(1)
# memory usage: 80.7 KB
#       user_id  month  total_round_minutes  total_calls_count  total_messages
# 94       1028      2                  NaN                NaN            12.0
# 381      1080      8                  NaN                NaN            31.0
# 382      1080      9                  NaN                NaN            64.0
# 383      1080     10                  NaN                NaN            59.0
# ...

# %%
accumulated.fillna(0, inplace=True)
accumulated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              2291 non-null   int64
#  1   month                2291 non-null   int32
#  2   total_round_minutes  2291 non-null   float64
#  3   total_calls_count    2291 non-null   float64
#  4   total_messages       2291 non-null   float64
# dtypes: float64(3), int32(1), int64(1)
# memory usage: 80.7 KB

# %%
accumulated = accumulated.merge(df_users, how='inner', on='user_id')
accumulated
# Out:
#       user_id  month  total_round_minutes  total_calls_count  total_messages  \
# 0        1000     12                117.0               16.0            11.0
# 1        1001      8                172.0               27.0            30.0
# 2        1001      9                298.0               49.0            44.0
# 3        1001     10                375.0               65.0            53.0
# 4        1001     11                405.0               64.0            36.0
# ...       ...    ...                  ...                ...             ...
# 2286     1498     12                325.0               39.0             0.0
# 2287     1499      9                331.0               41.0             0.0
# 2288     1499     10                364.0               53.0             0.0
# 2289     1499     11                289.0               45.0             0.0
# 2290     1499     12                469.0               65.0             0.0
#
# ...

# %%
accumulated = accumulated.merge(metrics_internet, how='outer', on=['user_id', 'month'])
accumulated
# Out:
#       user_id  month  total_round_minutes  total_calls_count  total_messages  \
# 0        1000     12                117.0               16.0            11.0
# 1        1001      8                172.0               27.0            30.0
# 2        1001      9                298.0               49.0            44.0
# 3        1001     10                375.0               65.0            53.0
# 4        1001     11                405.0               64.0            36.0
# ...       ...    ...                  ...                ...             ...
# 2288     1498     12                325.0               39.0             0.0
# 2289     1499      9                331.0               41.0             0.0
# 2290     1499     10                364.0               53.0             0.0
# 2291     1499     11                289.0               45.0             0.0
# 2292     1499     12                469.0               65.0             0.0
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Después del *outer merge* con el uso mensual de internet, `mb_used` tiene valores faltantes en los meses sin sesiones de internet. Estos NaNs pueden romper silenciosamente comparaciones/cálculos posteriores (p. ej., `NaN > value` es False). Considera rellenar los valores faltantes de `mb_used` con 0 después de este merge también.
#
# </div>

# %%
# Añade la información de la tarifa

accumulated = accumulated.merge(df_plans, how='inner', left_on='plan', right_on='plan_name')
accumulated
# Out:
#       user_id  month  total_round_minutes  total_calls_count  total_messages  \
# 0        1000     12                117.0               16.0            11.0
# 1        1001      8                172.0               27.0            30.0
# 2        1001      9                298.0               49.0            44.0
# 3        1001     10                375.0               65.0            53.0
# 4        1001     11                405.0               64.0            36.0
# ...       ...    ...                  ...                ...             ...
# 2286     1498     12                325.0               39.0             0.0
# 2287     1499      9                331.0               41.0             0.0
# 2288     1499     10                364.0               53.0             0.0
# 2289     1499     11                289.0               45.0             0.0
# 2290     1499     12                469.0               65.0             0.0
#
# ...

# %% [markdown]
# [Calcula los ingresos mensuales por usuario (resta el límite del paquete gratuito del número total de llamadas, mensajes de texto y datos; multiplica el resultado por el valor del plan de llamadas; añade la tarifa mensual en función del plan de llamadas). Nota: Dadas las condiciones del plan, ¡esto podría no ser tan trivial como un par de líneas! Así que no pasa nada si dedicas algo de tiempo a ello.]

# %%
# Calcula el ingreso mensual para cada usuario

def total_payment(row):
    payment = row['usd_monthly_pay']

    if row['total_round_minutes'] > row['minutes_included']:
        payment += row['total_round_minutes'] - row['minutes_included'] * row['usd_per_minute']

    if row['total_messages'] > row['messages_included']:
        payment += row['total_messages'] - row['messages_included'] * row['usd_per_message']

    if row['mb_used'] > row['mb_per_month_included']:
        payment += math.ceil((row['mb_used'] - row['mb_per_month_included'])/1024) * row['usd_per_gb']

    return payment

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# El cálculo de ingresos mensuales tiene dos problemas principales: (1) los cargos por exceso (overage) de minutos y mensajes se ven afectados por el orden de las operaciones, por lo que no estás multiplicando el uso *excedente* por el precio por unidad; (2) el exceso (overage) de internet debería basarse en el uso mensual redondeado hacia arriba a GB completos (después de sumar los MB mensuales), y compararse con la cantidad incluida del plan en GB. Tal como está escrito, estos problemas distorsionarán significativamente los resultados de ingresos.
#
# </div>

# %%
accumulated['payment'] = accumulated.apply(total_payment, axis=1)
accumulated
# Out:
#       user_id  month  total_round_minutes  total_calls_count  total_messages  \
# 0        1000     12                117.0               16.0            11.0
# 1        1001      8                172.0               27.0            30.0
# 2        1001      9                298.0               49.0            44.0
# 3        1001     10                375.0               65.0            53.0
# 4        1001     11                405.0               64.0            36.0
# ...       ...    ...                  ...                ...             ...
# 2286     1498     12                325.0               39.0             0.0
# 2287     1499      9                331.0               41.0             0.0
# 2288     1499     10                364.0               53.0             0.0
# 2289     1499     11                289.0               45.0             0.0
# 2290     1499     12                469.0               65.0             0.0
#
# ...

# %%
accumulated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2291 entries, 0 to 2290
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                2291 non-null   int64
#  1   month                  2291 non-null   int32
#  2   total_round_minutes    2291 non-null   float64
#  3   total_calls_count      2291 non-null   float64
#  4   total_messages         2291 non-null   float64
#  5   first_name             2291 non-null   object
#  6   last_name              2291 non-null   object
#  7   age                    2291 non-null   float64
#  8   city                   2291 non-null   object
#  9   reg_date               2291 non-null   object
#  10  plan                   2291 non-null   object
#  11  churn_date             2291 non-null   object
#  12  mb_used                2275 non-null   float64
#  13  messages_included      2291 non-null   int64
# ...

# %% [markdown]
# ## Estudia el comportamiento de usuario

# %% [markdown]
# [Calcula algunas estadísticas descriptivas para los datos agregados y fusionados que nos sean útiles y que muestren un panorama general captado por los datos. Dibuja gráficos útiles para facilitar la comprensión. Dado que la tarea principal es comparar las tarifas y decidir cuál es más rentable, las estadísticas y gráficas deben calcularse por tarifa.]
#
# [En los comentarios hallarás pistas relevantes para las llamadas, pero no las hay para los mensajes e Internet. Sin embargo, el principio del estudio estadístico que se aplica para ellos es el mismo que para las llamadas.]

# %% [markdown]
# ### Llamadas

# %%
# Compara la duración promedio de llamadas por cada plan y por cada mes. Traza un gráfico de barras para visualizarla.
accumulated.groupby(['plan', 'month'])['total_round_minutes'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='plan'>

# %%
# Compara el número de minutos mensuales que necesitan los usuarios de cada plan. Traza un histograma.
# accumulated.groupby('plan')['total_round_minutes'].mean().plot(kind='hist')
accumulated.query('plan == "surf"')['total_round_minutes'].hist()
accumulated.query('plan == "ultimate"')['total_round_minutes'].hist()

accumulated.groupby('plan')['total_round_minutes'].mean()
# Out:
# plan
# surf        405.24857
# ultimate    407.83844
# Name: total_round_minutes, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Al análisis de Internet le faltan los histogramas requeridos que comparen las distribuciones de uso mensual de Internet por plan. Tienes la media por mes y un boxplot, pero por favor añade histogramas y describe lo que muestran (forma, dispersión, solapamiento, outliers).
#
# </div>

# %% [markdown]
# [Calcula la media y la variable de la duración de las llamadas para averiguar si los usuarios de los distintos planes se comportan de forma diferente al realizar sus llamadas.]

# %%
# Calcula la media y la varianza de la duración mensual de llamadas.
accumulated.groupby('plan')['total_round_minutes'].agg(['mean', 'var'])
# Out:
#                mean           var
# plan
# surf      405.24857  49142.324306
# ultimate  407.83844  51331.251407

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas
sns.boxplot(x='plan', y='total_round_minutes', data=accumulated)
# Out:
# <Axes: xlabel='plan', ylabel='total_round_minutes'>

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a las llamadas. ¿Su comportamiento varía en función del plan?]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Aquí se dejó el prompt de plantilla entre corchetes. Por favor, reemplázalo con tus propias conclusiones sobre el comportamiento de las llamadas por plan, vinculando explícitamente tus afirmaciones con la media/varianza calculadas y con los gráficos (bar chart/histogram/boxplot).
#
# </div>

# %% [markdown]
# **R**
# - Total average minutes by months are longer in Ultimate than in Surf for some months, like month 2
# - Just in month 6 Surf is longer than Ultimate
# - The mean minutes for Surf and Ultimate are similar

# %% [markdown]
# ### Mensajes

# %%
# Comprara el número de mensajes que tienden a enviar cada mes los usuarios de cada plan
accumulated.groupby(['plan', 'month'])['total_messages'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='plan'>

# %%
# Calcula la media y la varianza del numero de mensajes
accumulated.groupby('plan')['total_messages'].agg(['mean', 'var'])
# Out:
#                mean          var
# plan
# surf      31.159568  1126.724522
# ultimate  37.655989  1208.184141

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas
sns.boxplot(x='plan', y='total_messages', data=accumulated)
# Out:
# <Axes: xlabel='plan', ylabel='total_messages'>

# %% [markdown]
# [Elabora las conclusiones sobre el comportamiento de los usuarios con respecto a los mensajes. ¿Su comportamiento varía en función del plan?]
#
# **R**
# - There is a slightly higher consumption of minutes in the Ultimate plan than in Surf
# - In Surf plan are more outliers values

# %% [markdown]
# ### Internet

# %%
# Compara la cantidad de tráfico de Internet consumido por usuarios por plan
accumulated.groupby(['plan', 'month'])['mb_used'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='plan'>

# %%
# Calcula la media y la varianza del tráfico de internet
accumulated.groupby('plan')['mb_used'].agg(['mean', 'var'])
# Out:
#                   mean           var
# plan
# surf      16718.197047  6.216815e+07
# ultimate  17284.813110  6.074395e+07

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas
sns.boxplot(x='plan', y='mb_used', data=accumulated)
# Out:
# <Axes: xlabel='plan', ylabel='mb_used'>

# %% [markdown]
# [Elabora las conclusiones sobre cómo los usuarios tienden a consumir el tráfico de Internet. ¿Su comportamiento varía en función del plan?]
#
# **R**
# - Total average megabytes by months are longer in Ulitmate plan than in Surf plan

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta conclusión sobre el uso de internet es demasiado breve para lo que pide la plantilla. Por favor, comenta la(s) distribución(es) por plan (dispersión/variabilidad, solapamiento, valores atípicos y cualquier asimetría notable) y conecta tu interpretación directamente con los resultados del histograma y el boxplot.
#
# </div>

# %% [markdown]
# ## Ingreso

# %% [markdown]
# [Del mismo modo que has estudiado el comportamiento de los usuarios, describe estadísticamente los ingresos de los planes.]

# %%
# Compara la cantidad de tráfico de Internet consumido por usuarios por plan
accumulated.groupby(['plan', 'month'])['payment'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='plan'>

# %%
# Calcula la media y la varianza del tráfico de internet
accumulated.groupby('plan')['payment'].agg(['mean', 'var'])
# Out:
#                 mean            var
# plan
# surf      274.353465  110220.278291
# ultimate   72.320334     130.195709

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas
sns.boxplot(x='plan', y='payment', data=accumulated)
# Out:
# <Axes: xlabel='plan', ylabel='payment'>

# %% [markdown]
# [Elabora las conclusiones sobre cómo difiere el ingreso entre los planes.]
#
# **R:**
#
# - Ultimate plan is more stable than Surf plan
# - The Surf plan has variable incomes and more expensives

# %% [markdown]
# ## Prueba las hipótesis estadísticas

# %% [markdown]
# [Prueba la hipótesis de que son diferentes los ingresos promedio procedentes de los usuarios de los planes de llamada Ultimate y Surf.]

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %%
# Prueba las hipótesis
# H0: El promedio mensual de surf y ultimate son iguales
# H1: El promedio mensual de surf es distinto al de ultimate
grupo_surf = accumulated.query('plan == "surf"')['payment']
grupo_ultimate = accumulated.query('plan == "ultimate"')['payment']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Este bloque de prueba de hipótesis está incompleto: defines H0/H1 y creas las muestras, pero no indicas explícitamente el alpha elegido, y aquí no ejecutas ni reportas los resultados de la prueba (p-value y conclusión). Incluye alpha e interpreta claramente la decisión estadística en esta sección.
#
# </div>

# %% [markdown]
# [Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.]

# %% [markdown]
# [Elabora las hipótesis nula y alternativa, escoge la prueba estadística, determina el valor alfa.]

# %%
# Prueba las hipótesis
result = stats.ttest_ind(grupo_surf, grupo_ultimate)

if result.pvalue < (1 - 0.95):
    print('Rechazamos la hipotesis nula')
else:
    print('No Rechazamos la hipotesis nula')
# Out:
# Rechazamos la hipotesis nula

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Esta celda aparece bajo la hipótesis de NY-NJ vs otras regiones, pero vuelve a ejecutar la prueba Surf vs Ultimate. Falta la prueba requerida de NY-NJ: necesitas definir dos muestras basadas en la ubicación (área NY-NJ vs todas las demás regiones), ejecutar la prueba adecuada con el alpha que indicaste y reportar la conclusión en ese contexto.
#
# </div>

# %% [markdown]
# ## Conclusión general
#
# [En esta sección final, enumera tus conclusiones importantes. Asegúrate de que estas abarquen todas las decisiones (suposiciones) importantes que adoptaste y que determinaron la forma elegida para procesar y analizar los datos.]
#
# **R:**
#
# - The Ultimate plan consume has a good configuration regarding to the MB, minutes and messages
# - The Surf plan is more profitable than the Ultimate plan
# - The high cost-effective could lead to dissatisfied customers

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# La conclusión final todavía contiene las instrucciones originales de la plantilla entre corchetes. Por favor, elimina todo el texto de orientación entre corchetes y conserva únicamente tus propias conclusiones resumidas, incluyendo cualquier suposición clave o decisión de procesamiento que haya afectado tus resultados.
#
# </div>
